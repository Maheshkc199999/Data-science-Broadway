# %%
import scipy.stats as stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore') 
sns.set(style="darkgrid") 
from scipy.stats import skew

# %%
df = pd.read_csv("C:/Users/HP/Downloads/insurance.csv")

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
sum(df.duplicated(subset = 'region'))
# Out:
# 1334

# %%
df_sym = pd.DataFrame(df['children'].value_counts())
print(df_sym)

print(df_sym.index.values)
df_sym.plot.pie(subplots=True,labels = df_sym.index.values, autopct='%1.2f%%', figsize = (15,7.5))
# Out:
#    children
# 0       574
# 1       324
# 2       240
# 3       157
# 4        25
# 5        18
# [0 1 2 3 4 5]
# array([<Axes: ylabel='children'>], dtype=object)

# %%
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
print(df[['region','expenses']].groupby("region").mean())  # sum() can also be used

plt1 = df[['region','expenses']].groupby("region").sum()
plt1.plot(kind='bar',legend = True,)
plt.xlabel("children")
plt.ylabel("Avg charges (Dollars)")
xticks(rotation = 45)
plt.show()
# Out:
#                expenses
# region
# northeast  13406.384691
# northwest  12417.575169
# southeast  14735.411538
# southwest  12346.937908

# %%
df_comp_avg_price = df[['region','children']].groupby("region", as_index = False).mean()
print(df_comp_avg_price)


plt1 = df_comp_avg_price.plot(x = 'region', kind='bar',legend = True, sort_columns = True, figsize = (15,3))
plt.xlabel("region")
plt.ylabel("Avg no. of children")
xticks(rotation = 90)
plt.show()
# Out:
#       region  children
# 0  northeast  1.046296
# 1  northwest  1.147692
# 2  southeast  1.049451
# 3  southwest  1.141538

# %%
df_comp_avg_price = df[['children','expenses']].groupby("children", as_index = False).mean()
print(df_comp_avg_price)
plt1 = df_comp_avg_price.plot(x = 'children', kind='bar',legend = True, sort_columns = True, figsize = (15,3))
plt1.set_xlabel("children")
plt1.set_ylabel("Avg charges ")
xticks(rotation = 90)
plt.show()
# Out:
#    children      expenses
# 0         0  12365.975767
# 1         1  12731.171821
# 2         2  15073.564000
# 3         3  15355.318535
# 4         4  13850.656800
# 5         5   8786.035556

# %%
df_comp_avg_price = df[['smoker','expenses']].groupby("smoker", as_index = False).mean()
print(df_comp_avg_price)

plt1 = df_comp_avg_price.plot(x = 'smoker', kind='bar',legend = True, sort_columns = True, figsize = (5,5))
plt1.set_xlabel("smoker")
plt1.set_ylabel("Avg charges ")
xticks(rotation = 90)
plt.show()
# Out:
#   smoker      expenses
# 0     no   8434.268449
# 1    yes  32050.231971

# %%
df_comp_avg_price = df[['smoker','bmi']].groupby("smoker", as_index = False).mean()
print(df_comp_avg_price)

plt1 = df_comp_avg_price.plot(x = 'smoker', kind='bar',legend = True, sort_columns = True, figsize = (5,5))
plt1.set_xlabel("smoker")
plt1.set_ylabel("bmi ")
xticks(rotation = 90)
plt.show()
# Out:
#   smoker        bmi
# 0     no  30.653195
# 1    yes  30.713139

# %%
plt.figure(figsize=(15, 15))
sns.pairplot(df[['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']])
plt.show()

# %%
auto=df[['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses']]

# %%
gender = pd.get_dummies(auto['sex'], drop_first = True)
gender
# Out:
#       male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 1333     1
# 1334     0
# 1335     0
# 1336     0
# 1337     0
#
# [1338 rows x 1 columns]

# %%
auto = pd.concat([auto, gender], axis = 1)
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses  male
# 0      19  female  27.9         0    yes  southwest  16884.92     0
# 1      18    male  33.8         1     no  southeast   1725.55     1
# 2      28    male  33.0         3     no  southeast   4449.46     1
# 3      33    male  22.7         0     no  northwest  21984.47     1
# 4      32    male  28.9         0     no  northwest   3866.86     1
# ...   ...     ...   ...       ...    ...        ...       ...   ...
# 1333   50    male  31.0         3     no  northwest  10600.55     1
# 1334   18  female  31.9         0     no  northeast   2205.98     0
# 1335   18  female  36.9         0     no  southeast   1629.83     0
# 1336   21  female  25.8         0     no  southwest   2007.95     0
# 1337   61  female  29.1         0    yes  northwest  29141.36     0
#
# [1338 rows x 8 columns]

# %%
region_typ = pd.get_dummies(auto['region'], drop_first = True)
region_typ
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
auto = pd.concat([auto, region_typ], axis = 1)
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses  male  \
# 0      19  female  27.9         0    yes  southwest  16884.92     0
# 1      18    male  33.8         1     no  southeast   1725.55     1
# 2      28    male  33.0         3     no  southeast   4449.46     1
# 3      33    male  22.7         0     no  northwest  21984.47     1
# 4      32    male  28.9         0     no  northwest   3866.86     1
# ...   ...     ...   ...       ...    ...        ...       ...   ...
# 1333   50    male  31.0         3     no  northwest  10600.55     1
# 1334   18  female  31.9         0     no  northeast   2205.98     0
# 1335   18  female  36.9         0     no  southeast   1629.83     0
# 1336   21  female  25.8         0     no  southwest   2007.95     0
# 1337   61  female  29.1         0    yes  northwest  29141.36     0
#
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 11 columns]

# %%
smoker = pd.get_dummies(auto['smoker'], drop_first = True)
smoker
# Out:
#       yes
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
#
# [1338 rows x 1 columns]

# %%
auto = pd.concat([auto, smoker], axis = 1)

# %%
auto
# Out:
#       age     sex   bmi  children smoker     region  expenses  male  \
# 0      19  female  27.9         0    yes  southwest  16884.92     0
# 1      18    male  33.8         1     no  southeast   1725.55     1
# 2      28    male  33.0         3     no  southeast   4449.46     1
# 3      33    male  22.7         0     no  northwest  21984.47     1
# 4      32    male  28.9         0     no  northwest   3866.86     1
# ...   ...     ...   ...       ...    ...        ...       ...   ...
# 1333   50    male  31.0         3     no  northwest  10600.55     1
# 1334   18  female  31.9         0     no  northeast   2205.98     0
# 1335   18  female  36.9         0     no  southeast   1629.83     0
# 1336   21  female  25.8         0     no  southwest   2007.95     0
# 1337   61  female  29.1         0    yes  northwest  29141.36     0
#
#       northwest  southeast  southwest  yes
# 0             0          0          1    1
# 1             0          1          0    0
# 2             0          1          0    0
# 3             1          0          0    0
# 4             1          0          0    0
# ...         ...        ...        ...  ...
# 1333          1          0          0    0
# 1334          0          0          0    0
# 1335          0          1          0    0
# 1336          0          0          1    0
# 1337          1          0          0    1
#
# [1338 rows x 12 columns]

# %%
auto.drop(['sex','region','smoker'], axis = 1, inplace = True)

# %%
auto
# Out:
#       age   bmi  children  expenses  male  northwest  southeast  southwest  \
# 0      19  27.9         0  16884.92     0          0          0          1
# 1      18  33.8         1   1725.55     1          0          1          0
# 2      28  33.0         3   4449.46     1          0          1          0
# 3      33  22.7         0  21984.47     1          1          0          0
# 4      32  28.9         0   3866.86     1          1          0          0
# ...   ...   ...       ...       ...   ...        ...        ...        ...
# 1333   50  31.0         3  10600.55     1          1          0          0
# 1334   18  31.9         0   2205.98     0          0          0          0
# 1335   18  36.9         0   1629.83     0          0          1          0
# 1336   21  25.8         0   2007.95     0          0          0          1
# 1337   61  29.1         0  29141.36     0          1          0          0
#
#       yes
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
#
# [1338 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(auto, train_size = 0.7, test_size = 0.3, random_state = 1)

# %%
df_train
# Out:
#       age   bmi  children  expenses  male  northwest  southeast  southwest  \
# 744    50  26.4         0   8827.21     1          1          0          0
# 363    21  26.4         1   2597.78     0          0          0          1
# 10     25  26.2         0   2721.32     1          0          0          0
# 970    50  28.2         3  10702.64     0          0          1          0
# 634    51  39.7         1   9391.35     1          0          0          1
# ...   ...   ...       ...       ...   ...        ...        ...        ...
# 715    60  28.9         0  12146.97     1          0          0          1
# 905    26  29.4         2   4564.19     0          0          0          0
# 1096   51  35.0         2  44641.20     0          0          0          0
# 235    40  22.2         2  19444.27     0          0          1          0
# 1061   57  27.9         1  11554.22     1          0          1          0
#
#       yes
# 744     0
# 363     0
# 10      0
# 970     0
# 634     0
# ...   ...
# 715     0
# 905     0
# 1096    1
# 235     1
# 1061    0
#
# [936 rows x 9 columns]

# %%
df_test
# Out:
#       age   bmi  children  expenses  male  northwest  southeast  southwest  \
# 559    19  35.5         0   1646.43     1          1          0          0
# 1087   57  31.5         0  11353.23     1          1          0          0
# 1020   51  37.0         0   8798.59     1          0          0          1
# 460    49  36.6         3  10381.48     0          0          1          0
# 802    21  22.3         1   2103.08     1          0          0          1
# ...   ...   ...       ...       ...   ...        ...        ...        ...
# 323    57  40.9         0  11566.30     1          0          0          0
# 1268   20  33.3         0   1880.49     0          0          0          1
# 134    20  28.8         0   2457.21     0          0          0          0
# 1274   26  27.1         0  17043.34     1          0          1          0
# 876    49  27.1         1  26140.36     0          0          0          1
#
#       yes
# 559     0
# 1087    0
# 1020    0
# 460     0
# 802     0
# ...   ...
# 323     0
# 1268    0
# 134     0
# 1274    1
# 876     0
#
# [402 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler
# Out:
# MinMaxScaler()

# %%
df_train.head()
# Out:
#      age   bmi  children  expenses  male  northwest  southeast  southwest  yes
# 744   50  26.4         0   8827.21     1          1          0          0    0
# 363   21  26.4         1   2597.78     0          0          0          1    0
# 10    25  26.2         0   2721.32     1          0          0          0    0
# 970   50  28.2         3  10702.64     0          0          1          0    0
# 634   51  39.7         1   9391.35     1          0          0          1    0

# %%
df_train.describe()
# Out:
#               age         bmi    children      expenses        male  \
# count  936.000000  936.000000  936.000000    936.000000  936.000000
# mean    38.822650   30.684829    1.104701  13276.698622    0.511752
# std     14.029097    6.087874    1.222664  12197.308146    0.500129
# min     18.000000   16.000000    0.000000   1121.870000    0.000000
# 25%     26.000000   26.275000    0.000000   4710.600000    0.000000
# 50%     38.000000   30.500000    1.000000   9188.005000    1.000000
# 75%     51.000000   34.725000    2.000000  16604.305000    1.000000
# max     64.000000   53.100000    5.000000  63770.430000    1.000000
#
#         northwest   southeast   southwest         yes
# count  936.000000  936.000000  936.000000  936.000000
# mean     0.238248    0.264957    0.256410    0.206197
# std      0.426239    0.441546    0.436884    0.404790
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000

# %%
num_vars = ['age', 'bmi', 'children', 'expenses']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#           age       bmi  children  expenses  male  northwest  southeast  \
# 744  0.695652  0.280323       0.0  0.122993     1          1          0
# 363  0.065217  0.280323       0.2  0.023559     0          0          0
# 10   0.152174  0.274933       0.0  0.025531     1          0          0
# 970  0.695652  0.328841       0.6  0.152929     0          0          1
# 634  0.717391  0.638814       0.2  0.131998     1          0          0
#
#      southwest  yes
# 744          0    0
# 363          1    0
# 10           0    0
# 970          0    0
# 634          1    0

# %%
df_train.describe()
# Out:
#               age         bmi    children    expenses        male   northwest  \
# count  936.000000  936.000000  936.000000  936.000000  936.000000  936.000000
# mean     0.452666    0.395817    0.220940    0.194016    0.511752    0.238248
# std      0.304980    0.164094    0.244533    0.194694    0.500129    0.426239
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.173913    0.276954    0.000000    0.057284    0.000000    0.000000
# 50%      0.434783    0.390836    0.200000    0.128752    1.000000    0.000000
# 75%      0.717391    0.504717    0.400000    0.247132    1.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         southeast   southwest         yes
# count  936.000000  936.000000  936.000000
# mean     0.264957    0.256410    0.206197
# std      0.441546    0.436884    0.404790
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True,)
plt.show()

# %%
y_train = df_train.pop('expenses')
X_train = df_train

# %%
y_train
# Out:
# 744     0.122993
# 363     0.023559
# 10      0.025531
# 970     0.152929
# 634     0.131998
#           ...
# 715     0.175983
# 905     0.054947
# 1096    0.694658
# 235     0.292463
# 1061    0.166522
# Name: expenses, Length: 936, dtype: float64

# %%
X_train
# Out:
#            age       bmi  children  male  northwest  southeast  southwest  yes
# 744   0.695652  0.280323       0.0     1          1          0          0    0
# 363   0.065217  0.280323       0.2     0          0          0          1    0
# 10    0.152174  0.274933       0.0     1          0          0          0    0
# 970   0.695652  0.328841       0.6     0          0          1          0    0
# 634   0.717391  0.638814       0.2     1          0          0          1    0
# ...        ...       ...       ...   ...        ...        ...        ...  ...
# 715   0.913043  0.347709       0.0     1          0          0          1    0
# 905   0.173913  0.361186       0.4     0          0          0          0    0
# 1096  0.717391  0.512129       0.4     0          0          0          0    1
# 235   0.478261  0.167116       0.4     0          0          1          0    1
# 1061  0.847826  0.320755       0.2     1          0          1          0    0
#
# [936 rows x 8 columns]

# %%
prediction_data = df_test.iloc[0:1][['age','bmi','children','male','northwest','southeast','southwest','yes']]

# %%
prediction_data = df_test.iloc[0:1][['age','bmi','children','male','northwest','southeast','southwest','yes']]
lm = LinearRegression()
model = lm.fit(X_train, y_train)
model.predict(prediction_data)
# Out:
# array([10.24283447])

# %%
lm = LinearRegression()
rfe = RFE(lm, n_features_to_select=10)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('age', True, 1),
#  ('bmi', True, 1),
#  ('children', True, 1),
#  ('male', True, 1),
#  ('northwest', True, 1),
#  ('southeast', True, 1),
#  ('southwest', True, 1),
#  ('yes', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['age', 'bmi', 'children', 'male', 'northwest', 'southeast', 'southwest',
#        'yes'],
#       dtype='object')

# %%
X_train_rfe = X_train[col]

# %%
import statsmodels.api as sm
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
X_train_rfe
# Out:
#       const       age       bmi  children  male  northwest  southeast  \
# 744     1.0  0.695652  0.280323       0.0     1          1          0
# 363     1.0  0.065217  0.280323       0.2     0          0          0
# 10      1.0  0.152174  0.274933       0.0     1          0          0
# 970     1.0  0.695652  0.328841       0.6     0          0          1
# 634     1.0  0.717391  0.638814       0.2     1          0          0
# ...     ...       ...       ...       ...   ...        ...        ...
# 715     1.0  0.913043  0.347709       0.0     1          0          0
# 905     1.0  0.173913  0.361186       0.4     0          0          0
# 1096    1.0  0.717391  0.512129       0.4     0          0          0
# 235     1.0  0.478261  0.167116       0.4     0          0          1
# 1061    1.0  0.847826  0.320755       0.2     1          0          1
#
#       southwest  yes
# 744           0    0
# 363           1    0
# 10            0    0
# 970           0    0
# 634           1    0
# ...         ...  ...
# 715           1    0
# 905           0    0
# 1096          0    1
# 235           0    1
# 1061          0    0
#
# [936 rows x 9 columns]

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.755
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     356.3
# Date:                Fri, 19 Jan 2024   Prob (F-statistic):          1.22e-276
# Time:                        19:46:24   Log-Likelihood:                 861.41
# No. Observations:                 936   AIC:                            -1705.
# Df Residuals:                     927   BIC:                            -1661.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0395      0.011     -3.548      0.000      -0.061      -0.018
# age            0.1848      0.010     17.636      0.000       0.164       0.205
# bmi            0.1910      0.020      9.417      0.000       0.151       0.231
# children       0.0275      0.013      2.119      0.034       0.002       0.053
# male          -0.0045      0.006     -0.709      0.478      -0.017       0.008
# northwest     -0.0048      0.009     -0.528      0.598      -0.023       0.013
# southeast     -0.0150      0.009     -1.627      0.104      -0.033       0.003
# southwest     -0.0138      0.009     -1.529      0.126      -0.032       0.004
# yes            0.3840      0.008     48.901      0.000       0.369       0.399
# ==============================================================================
# Omnibus:                      207.463   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              491.567
# Skew:                           1.182   Prob(JB):                    1.81e-107
# Kurtosis:                       5.648   Cond. No.                         9.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_new1 = X_train_rfe.drop(["northwest"], axis = 1)

X_train_new1
# Out:
#       const       age       bmi  children  male  southeast  southwest  yes
# 744     1.0  0.695652  0.280323       0.0     1          0          0    0
# 363     1.0  0.065217  0.280323       0.2     0          0          1    0
# 10      1.0  0.152174  0.274933       0.0     1          0          0    0
# 970     1.0  0.695652  0.328841       0.6     0          1          0    0
# 634     1.0  0.717391  0.638814       0.2     1          0          1    0
# ...     ...       ...       ...       ...   ...        ...        ...  ...
# 715     1.0  0.913043  0.347709       0.0     1          0          1    0
# 905     1.0  0.173913  0.361186       0.4     0          0          0    0
# 1096    1.0  0.717391  0.512129       0.4     0          0          0    1
# 235     1.0  0.478261  0.167116       0.4     0          1          0    1
# 1061    1.0  0.847826  0.320755       0.2     1          1          0    0
#
# [936 rows x 8 columns]

# %%
lm = sm.OLS(y_train,X_train_new1).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.755
# Model:                            OLS   Adj. R-squared:                  0.753
# Method:                 Least Squares   F-statistic:                     407.4
# Date:                Fri, 19 Jan 2024   Prob (F-statistic):          6.68e-278
# Time:                        19:47:53   Log-Likelihood:                 861.27
# No. Observations:                 936   AIC:                            -1707.
# Df Residuals:                     928   BIC:                            -1668.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0418      0.010     -4.085      0.000      -0.062      -0.022
# age            0.1847      0.010     17.637      0.000       0.164       0.205
# bmi            0.1908      0.020      9.412      0.000       0.151       0.231
# children       0.0272      0.013      2.096      0.036       0.002       0.053
# male          -0.0044      0.006     -0.687      0.492      -0.017       0.008
# southeast     -0.0126      0.008     -1.573      0.116      -0.028       0.003
# southwest     -0.0114      0.008     -1.465      0.143      -0.027       0.004
# yes            0.3841      0.008     48.958      0.000       0.369       0.400
# ==============================================================================
# Omnibus:                      206.240   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              485.615
# Skew:                           1.178   Prob(JB):                    3.55e-106
# Kurtosis:                       5.626   Cond. No.                         9.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_new2 = X_train_new1.drop(["male"], axis = 1)

lm = sm.OLS(y_train,X_train_new2).fit()   
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.753
# Method:                 Least Squares   F-statistic:                     475.5
# Date:                Fri, 19 Jan 2024   Prob (F-statistic):          3.72e-279
# Time:                        19:49:06   Log-Likelihood:                 861.03
# No. Observations:                 936   AIC:                            -1708.
# Df Residuals:                     929   BIC:                            -1674.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0437      0.010     -4.438      0.000      -0.063      -0.024
# age            0.1847      0.010     17.643      0.000       0.164       0.205
# bmi            0.1901      0.020      9.392      0.000       0.150       0.230
# children       0.0270      0.013      2.086      0.037       0.002       0.052
# southeast     -0.0125      0.008     -1.566      0.118      -0.028       0.003
# southwest     -0.0114      0.008     -1.461      0.144      -0.027       0.004
# yes            0.3838      0.008     49.030      0.000       0.368       0.399
# ==============================================================================
# Omnibus:                      207.240   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              489.976
# Skew:                           1.182   Prob(JB):                    4.01e-107
# Kurtosis:                       5.641   Cond. No.                         8.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_new3 = X_train_new2.drop(["southwest"], axis = 1)
lm = sm.OLS(y_train,X_train_new3).fit()

# %%
X_train_new4 = X_train_new3.drop(["southeast"], axis = 1)
lm = sm.OLS(y_train,X_train_new4).fit()

# %%
X_train_new5 = X_train_new4.drop(["children"], axis = 1)

lm = sm.OLS(y_train,X_train_new5).fit() 
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               expenses   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     943.6
# Date:                Fri, 19 Jan 2024   Prob (F-statistic):          7.72e-282
# Time:                        19:51:37   Log-Likelihood:                 857.10
# No. Observations:                 936   AIC:                            -1706.
# Df Residuals:                     932   BIC:                            -1687.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0407      0.009     -4.394      0.000      -0.059      -0.023
# age            0.1857      0.010     17.710      0.000       0.165       0.206
# bmi            0.1809      0.019      9.284      0.000       0.143       0.219
# yes            0.3834      0.008     48.895      0.000       0.368       0.399
# ==============================================================================
# Omnibus:                      204.145   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              471.652
# Skew:                           1.175   Prob(JB):                    3.82e-103
# Kurtosis:                       5.563   Cond. No.                         7.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df_test
# Out:
#       age   bmi  children  expenses  male  northwest  southeast  southwest  \
# 559    19  35.5         0   1646.43     1          1          0          0
# 1087   57  31.5         0  11353.23     1          1          0          0
# 1020   51  37.0         0   8798.59     1          0          0          1
# 460    49  36.6         3  10381.48     0          0          1          0
# 802    21  22.3         1   2103.08     1          0          0          1
# ...   ...   ...       ...       ...   ...        ...        ...        ...
# 323    57  40.9         0  11566.30     1          0          0          0
# 1268   20  33.3         0   1880.49     0          0          0          1
# 134    20  28.8         0   2457.21     0          0          0          0
# 1274   26  27.1         0  17043.34     1          0          1          0
# 876    49  27.1         1  26140.36     0          0          0          1
#
#       yes
# 559     0
# 1087    0
# 1020    0
# 460     0
# 802     0
# ...   ...
# 323     0
# 1268    0
# 134     0
# 1274    1
# 876     0
#
# [402 rows x 9 columns]

# %%
num_vars = ['age', 'bmi', 'children', 'expenses']

df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
df_test
# Out:
#            age       bmi  children  expenses  male  northwest  southeast  \
# 559   0.021739  0.525606       0.0  0.008373     1          1          0
# 1087  0.847826  0.417790       0.0  0.163314     1          1          0
# 1020  0.717391  0.566038       0.0  0.122536     1          0          0
# 460   0.673913  0.555256       0.6  0.147802     0          0          1
# 802   0.065217  0.169811       0.2  0.015662     1          0          0
# ...        ...       ...       ...       ...   ...        ...        ...
# 323   0.847826  0.671159       0.0  0.166715     1          0          0
# 1268  0.043478  0.466307       0.0  0.012109     0          0          0
# 134   0.043478  0.345013       0.0  0.021315     0          0          0
# 1274  0.173913  0.299191       0.0  0.254139     1          0          1
# 876   0.673913  0.299191       0.2  0.399347     0          0          0
#
#       southwest  yes
# 559           0    0
# 1087          0    0
# 1020          1    0
# 460           0    0
# 802           1    0
# ...         ...  ...
# 323           0    0
# 1268          1    0
# 134           0    0
# 1274          0    1
# 876           1    0
#
# [402 rows x 9 columns]

# %%
y_test = df_test.pop('expenses')
X_test = df_test

# %%
y_test
# Out:
# 559     0.008373
# 1087    0.163314
# 1020    0.122536
# 460     0.147802
# 802     0.015662
#           ...
# 323     0.166715
# 1268    0.012109
# 134     0.021315
# 1274    0.254139
# 876     0.399347
# Name: expenses, Length: 402, dtype: float64

# %%
X_test_new = X_test[['age','bmi','yes']]

X_test_new
# Out:
#            age       bmi  yes
# 559   0.021739  0.525606    0
# 1087  0.847826  0.417790    0
# 1020  0.717391  0.566038    0
# 460   0.673913  0.555256    0
# 802   0.065217  0.169811    0
# ...        ...       ...  ...
# 323   0.847826  0.671159    0
# 1268  0.043478  0.466307    0
# 134   0.043478  0.345013    0
# 1274  0.173913  0.299191    1
# 876   0.673913  0.299191    0
#
# [402 rows x 3 columns]

# %%
X_test_new = sm.add_constant(X_test_new)
X_test_new
# Out:
#       const       age       bmi  yes
# 559     1.0  0.021739  0.525606    0
# 1087    1.0  0.847826  0.417790    0
# 1020    1.0  0.717391  0.566038    0
# 460     1.0  0.673913  0.555256    0
# 802     1.0  0.065217  0.169811    0
# ...     ...       ...       ...  ...
# 323     1.0  0.847826  0.671159    0
# 1268    1.0  0.043478  0.466307    0
# 134     1.0  0.043478  0.345013    0
# 1274    1.0  0.173913  0.299191    1
# 876     1.0  0.673913  0.299191    0
#
# [402 rows x 4 columns]

# %%
y_pred = lm.predict(X_test_new)
y_pred
# Out:
# 559     0.058427
# 1087    0.192294
# 1020    0.194896
# 460     0.184873
# 802     0.002135
#           ...
# 323     0.238129
# 1268    0.051735
# 134     0.029793
# 1274    0.429152
# 876     0.138551
# Length: 402, dtype: float64

# %%
y_test
# Out:
# 559     0.008373
# 1087    0.163314
# 1020    0.122536
# 460     0.147802
# 802     0.015662
#           ...
# 323     0.166715
# 1268    0.012109
# 134     0.021315
# 1274    0.254139
# 876     0.399347
# Name: expenses, Length: 402, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7349571372480102

# %%
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)         
plt.xlabel('y_test', fontsize=18)    
plt.ylabel('y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'y_pred')
